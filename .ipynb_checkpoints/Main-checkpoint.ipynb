# %% [markdown]
# # DataSci Summaritive File
#
# **Matteo Esposito | Summer 2018**

# %% [markdown]
# ## Packages

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import os
# %matplotlib inline

# %% [markdown]
# ### os

# %%
# Change working directory and load in data
os.chdir("/Users/Matteo/Github/PyProjects/data/")
df = pd.read_csv("wc_matches.csv")

# %% [markdown]
# ### numpy

# %%
df.head()
df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 20 columns):
# date           64 non-null object
# league_id      64 non-null int64
# league         64 non-null object
# team1          64 non-null object
# team2          64 non-null object
# spi1           64 non-null float64
# spi2           64 non-null float64
# prob1          64 non-null float64
# prob2          64 non-null float64
# probtie        64 non-null float64
# proj_score1    64 non-null float64
# proj_score2    64 non-null float64
# score1         64 non-null int64
# score2         64 non-null int64
# xg1            64 non-null float64
# xg2            64 non-null float64
# nsxg1          64 non-null float64
# nsxg2          64 non-null float64
# adj_score1     64 non-null float64
# adj_score2     64 non-null float64
# dtypes: float64(13), int64(3), object(4)
# memory usage: 10.1+ KB

# %%
df[:3]
# Out:
#          date  league_id          league    team1         team2   spi1   spi2  \
# 0  2018-06-14       1908  FIFA World Cup   Russia  Saudi Arabia  70.14  51.33
# 1  2018-06-15       1908  FIFA World Cup    Egypt       Uruguay  62.46  79.52
# 2  2018-06-15       1908  FIFA World Cup  Morocco          Iran  72.33  65.57
#
#     prob1   prob2  probtie  proj_score1  proj_score2  score1  score2   xg1  \
# 0  0.6615  0.1200   0.2184         2.03         0.73       5       0  1.62
# 1  0.1845  0.5433   0.2723         0.82         1.61       0       1  0.42
# 2  0.4004  0.2667   0.3330         1.13         0.86       0       1  0.86
#
#     xg2  nsxg1  nsxg2  adj_score1  adj_score2
# 0  0.20   1.55   0.11        4.18        0.00
# 1  1.94   0.65   1.94        0.00        1.05
# 2  0.72   0.57   0.36        0.00        1.05

# %%
# number of columns
df.shape[1]
# Out:
# 20

# %%
# number of rows
df.shape[0]
# Out:
# 64

# %% [markdown]
# ### pandas

# %%
df["team1"].head()
# Out:
# 0      Russia
# 1       Egypt
# 2     Morocco
# 3    Portugal
# 4      France
# Name: team1, dtype: object

# %%
df[["team1","team2"]].head()
# Out:
#       team1         team2
# 0    Russia  Saudi Arabia
# 1     Egypt       Uruguay
# 2   Morocco          Iran
# 3  Portugal         Spain
# 4    France     Australia

# %%
##NOTE: This doesn't remove the column from the table in memory
df.drop('team1',axis=1).head()
# Out:
#          date  league_id          league         team2   spi1   spi2   prob1  \
# 0  2018-06-14       1908  FIFA World Cup  Saudi Arabia  70.14  51.33  0.6615
# 1  2018-06-15       1908  FIFA World Cup       Uruguay  62.46  79.52  0.1845
# 2  2018-06-15       1908  FIFA World Cup          Iran  72.33  65.57  0.4004
# 3  2018-06-15       1908  FIFA World Cup         Spain  83.47  91.30  0.2459
# 4  2018-06-16       1908  FIFA World Cup     Australia  87.18  61.69  0.7694
#
#     prob2  probtie  proj_score1  proj_score2  score1  score2   xg1   xg2  \
# 0  0.1200   0.2184         2.03         0.73       5       0  1.62  0.20
# 1  0.5433   0.2723         0.82         1.61       0       1  0.42  1.94
# 2  0.2667   0.3330         1.13         0.86       0       1  0.86  0.72
# 3  0.4809   0.2732         1.07         1.60       3       3  1.15  1.63
# 4  0.0746   0.1560         2.61         0.69       2       1  1.38  1.03
#
#    nsxg1  nsxg2  adj_score1  adj_score2
# ...

# %%
## Useful if your index is not the std. numerical type
## i.e. A,B,C,... (label not position)
df.iloc[0].head()
# Out:
# date             2018-06-14
# league_id              1908
# league       FIFA World Cup
# team1                Russia
# team2          Saudi Arabia
# Name: 0, dtype: object

# %%
df.loc[0].head()
# Out:
# date             2018-06-14
# league_id              1908
# league       FIFA World Cup
# team1                Russia
# team2          Saudi Arabia
# Name: 0, dtype: object

# %%
# Reset to default 0,1...n index
df.reset_index().head()
# Out:
#    index        date  league_id          league     team1         team2  \
# 0      0  2018-06-14       1908  FIFA World Cup    Russia  Saudi Arabia
# 1      1  2018-06-15       1908  FIFA World Cup     Egypt       Uruguay
# 2      2  2018-06-15       1908  FIFA World Cup   Morocco          Iran
# 3      3  2018-06-15       1908  FIFA World Cup  Portugal         Spain
# 4      4  2018-06-16       1908  FIFA World Cup    France     Australia
#
#     spi1   spi2   prob1   prob2     ...      proj_score1  proj_score2  score1  \
# 0  70.14  51.33  0.6615  0.1200     ...             2.03         0.73       5
# 1  62.46  79.52  0.1845  0.5433     ...             0.82         1.61       0
# 2  72.33  65.57  0.4004  0.2667     ...             1.13         0.86       0
# 3  83.47  91.30  0.2459  0.4809     ...             1.07         1.60       3
# 4  87.18  61.69  0.7694  0.0746     ...             2.61         0.69       2
#
#    score2   xg1   xg2  nsxg1  nsxg2  adj_score1  adj_score2
# ...

# %%
df['team1'].unique()
# Out:
# array(['Russia', 'Egypt', 'Morocco', 'Portugal', 'France', 'Argentina',
#        'Peru', 'Croatia', 'Costa Rica', 'Germany', 'Brazil', 'Sweden',
#        'Belgium', 'Tunisia', 'Colombia', 'Poland', 'Uruguay', 'Iran',
#        'Denmark', 'Nigeria', 'Serbia', 'South Korea', 'England', 'Japan',
#        'Saudi Arabia', 'Spain', 'Australia', 'Iceland', 'Mexico',
#        'Switzerland', 'Senegal', 'Panama'], dtype=object)

# %%
df['team1'].nunique()
# Out:
# 32

# %%
# Very powerful command (frequency table)
df['team1'].value_counts().head()
# Out:
# France     5
# Belgium    4
# Brazil     4
# Uruguay    4
# Russia     3
# Name: team1, dtype: int64

# %%
def times2(x):
    return x*2

df['spi1'].apply(times2).head()
# Out:
# 0    140.28
# 1    124.92
# 2    144.66
# 3    166.94
# 4    174.36
# Name: spi1, dtype: float64

# %%
# Deleting column by name
del df['league']

# %% [markdown]
# ## Useful Operations

# %% [markdown]
# ### NAs

# %%
df.head()
# Out:
#          date  league_id     team1         team2   spi1   spi2   prob1  \
# 0  2018-06-14       1908    Russia  Saudi Arabia  70.14  51.33  0.6615
# 1  2018-06-15       1908     Egypt       Uruguay  62.46  79.52  0.1845
# 2  2018-06-15       1908   Morocco          Iran  72.33  65.57  0.4004
# 3  2018-06-15       1908  Portugal         Spain  83.47  91.30  0.2459
# 4  2018-06-16       1908    France     Australia  87.18  61.69  0.7694
#
#     prob2  probtie  proj_score1  proj_score2  score1  score2   xg1   xg2  \
# 0  0.1200   0.2184         2.03         0.73       5       0  1.62  0.20
# 1  0.5433   0.2723         0.82         1.61       0       1  0.42  1.94
# 2  0.2667   0.3330         1.13         0.86       0       1  0.86  0.72
# 3  0.4809   0.2732         1.07         1.60       3       3  1.15  1.63
# 4  0.0746   0.1560         2.61         0.69       2       1  1.38  1.03
#
#    nsxg1  nsxg2  adj_score1  adj_score2
# 0   1.55   0.11        4.18        0.00
# ...

# %%
## NA counter function for each column
def naCount(table):
    return table.isnull().sum()

naCount(df)
# Out:
# date           0
# league_id      0
# team1          0
# team2          0
# spi1           0
# spi2           0
# prob1          0
# prob2          0
# probtie        0
# proj_score1    0
# proj_score2    0
# score1         0
# score2         0
# xg1            0
# xg2            0
# nsxg1          0
# nsxg2          0
# adj_score1     0
# adj_score2     0
# dtype: int64

# %%
## Drop NAs
df.dropna(axis=1)
df.dropna(thresh=2) # Set cap for amount of NAs

## Mean imputation
df['score1'].fillna(value=df['score1'].mean())
# Out:
# 0     5
# 1     0
# 2     0
# 3     3
# 4     2
# 5     1
# 6     0
# 7     2
# 8     0
# 9     0
# 10    1
# 11    1
# 12    3
# 13    1
# 14    1
# 15    1
# 16    3
# 17    1
# 18    1
# 19    0
# 20    1
# 21    1
# 22    0
# 23    2
# 24    2
# 25    1
# 26    5
# 27    1
# 28    2
# 29    6
#      ..
# 34    2
# 35    1
# 36    0
# 37    0
# 38    1
# 39    1
# 40    2
# 41    0
# 42    0
# 43    2
# 44    0
# 45    0
# 46    0
# 47    1
# 48    4
# 49    2
# 50    1
# 51    1
# 52    2
# 53    3
# 54    1
# 55    1
# 56    0
# 57    1
# 58    0
# 59    2
# 60    1
# 61    2
# 62    2
# 63    4
# Name: score1, Length: 64, dtype: int64

# %% [markdown]
# ### SQL

# %% [markdown]
# #### Group by

# %%
## Group by
by_t1 = df.groupby("team1")
by_t1.mean()
by_t1.min()
by_t1.max()
# Out:
#                     date  league_id         team2   spi1   spi2   prob1  \
# team1
# Argentina     2018-06-21       1908       Iceland  87.41  81.11  0.6091
# Australia     2018-06-26       1908          Peru  63.58  71.65  0.2611
# Belgium       2018-07-14       1908       Tunisia  86.69  84.23  0.7679
# Brazil        2018-07-06       1908   Switzerland  93.09  87.35  0.8219
# Colombia      2018-07-03       1908         Japan  80.53  84.16  0.4844
# Costa Rica    2018-06-17       1908        Serbia  64.90  73.82  0.2312
# Croatia       2018-07-11       1908       Nigeria  82.23  85.17  0.6326
# Denmark       2018-06-26       1908        France  74.38  86.49  0.5394
# Egypt         2018-06-15       1908       Uruguay  62.46  79.52  0.1845
# England       2018-06-28       1908        Panama  85.11  86.36  0.7574
# France        2018-07-15       1908          Peru  88.05  87.50  0.7694
# Germany       2018-06-23       1908        Sweden  90.61  75.78  0.6276
# ...

# %%
## More detailed statistical analysis by team1
by_t1.describe().transpose()
# Out:
# team1               Argentina  Australia      Belgium       Brazil  \
# adj_score1 count     2.000000       1.00     4.000000     4.000000
#            mean      0.525000       0.00     3.180000     1.327500
#            std       0.742462        NaN     1.205736     0.321079
#            min       0.000000       0.00     1.800000     1.050000
#            25%       0.262500       0.00     2.722500     1.050000
#            50%       0.525000       0.00     3.090000     1.315000
#            75%       0.787500       0.00     3.547500     1.592500
#            max       1.050000       0.00     4.740000     1.630000
# adj_score2 count     2.000000       1.00     4.000000     4.000000
#            mean      1.705000       2.10     1.050000     0.787500
#            std       0.926310        NaN     1.212436     1.005298
#            min       1.050000       2.10     0.000000     0.000000
#            25%       1.377500       2.10     0.000000     0.000000
# ...

# %% [markdown]
# #### Joins/Merges

# %%
## Creating datasets for joins
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])

df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7]) 
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11']},
                        index=[8, 9, 10, 11])

# %%
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3],axis=1)
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})

# %%
pd.merge(left,right,how='inner',on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
left = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2']) 

right = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

# %%
left.join(right)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
left.join(right, how='outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %% [markdown]
# ### I/O

# %%
## In csv
df = pd.read_csv('example')

## Out csv
df = pd.to_csv('example')

## In xlsx
pd.read_excel('Excel_Sample.xlsx',sheetname='Sheet1')

## Out xlsx
pd.to_excel('Excel_Sample.xlsx',sheetname='Sheet1')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-b9ab04fc7453> in <module>()
#       1 ## In csv
# ----> 2 df = pd.read_csv('example')
#       3
#       4 ## Out csv
#       5 df = pd.to_csv('example')
#
# ...

# %%
## Add lambda functions + applys

# %% [markdown]
# ## Data Visualization

# %%
# seaborn, cufflinks, matplotlib, interactive graphs, etc..

# %% [markdown]
# ## Model Data Preparation

# %%
# dummy vars
# converting to useable data types (i.e. remove str and obj dtypes)
# pca
df.dtypes
# Out:
# date            object
# league_id        int64
# team1           object
# team2           object
# spi1           float64
# spi2           float64
# prob1          float64
# prob2          float64
# probtie        float64
# proj_score1    float64
# proj_score2    float64
# score1           int64
# score2           int64
# xg1            float64
# xg2            float64
# nsxg1          float64
# nsxg2          float64
# adj_score1     float64
# adj_score2     float64
# dtype: object

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Train/Test Splitting

# %%
from sklearn.model_selection import train_test_split
      
y = df['proj_score1'].values
X = df.drop('proj_score1',axis=1).values
        
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,
                                                 random_state = 123, 
                                                 stratify = y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-a043e7ffeec8> in <module>()
#       6 X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,
#       7                                                  random_state = 123,
# ----> 8                                                  stratify = y)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py in train_test_split(*arrays, **options)
#    2054                      random_state=random_state)
#    2055
# -> 2056         train, test = next(cv.split(X=arrays[0], y=stratify))
#    2057
#    2058     return list(chain.from_iterable((safe_indexing(a, train),
#
# /anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#    1202         """
#    1203         X, y, groups = indexable(X, y, groups)
# ...

# %%
X.head()

# %% [markdown]
# ### Classification

# %% [markdown]
# #### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=6, weights='uniform', 
                            algorithm='auto', leaf_size=30, p=2, 
                            metric='minkowski')
    
knn.fit(X_train,y_train)
knn.predict(X_test)
knn.score(X_test,y_test)

## Plot of training vs. test accuracy

# Setup arrays to store train and test accuracies
neighbors = np.arange(1, 9)
train_accuracy = np.empty(len(neighbors))
test_accuracy = np.empty(len(neighbors))

# Loop over different values of k
for i, k in enumerate(neighbors):
    # Setup a k-NN Classifier with k neighbors: knn
    knn = KNeighborsClassifier(n_neighbors=k)

    # Fit the classifier to the training data
    knn.fit(X_train,y_train)
    
    #Compute accuracy on the training set
    train_accuracy[i] = knn.score(X_train, y_train)

    #Compute accuracy on the testing set
    test_accuracy[i] = knn.score(X_test, y_test)

# Generate plot
plt.title('k-NN: Varying Number of Neighbors')
plt.plot(neighbors, test_accuracy, label = 'Testing Accuracy')
plt.plot(neighbors, train_accuracy, label = 'Training Accuracy')
plt.legend()
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-e6b572344799> in <module>()
#       8 X = df.drop('proj_score1',axis=1).values
#       9
# ---> 10 knn.fit(X,y)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/neighbors/base.py in fit(self, X, y)
#     763         """
#     764         if not isinstance(X, (KDTree, BallTree)):
# --> 765             X, y = check_X_y(X, y, "csr", multi_output=True)
#     766
#     767         if y.ndim == 1 or y.ndim == 2 and y.shape[1] == 1:
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...

# %% [markdown]
# ### Regression

# %% [markdown]
# #### Linear Regression

# %%
# Import LinearRegression
from sklearn.linear_model import LinearRegression

# Create the regressor: reg
reg = LinearRegression()

# Create the prediction space
prediction_space = np.linspace(min(X_fertility), max(X_fertility)).reshape(-1,1)

# Fit the model to the data
reg.fit(X_fertility,y)

# Compute predictions over the prediction space: y_pred
y_pred = reg.predict(prediction_space)

# Print R^2 
print(reg.score(X_fertility, y))

# Plot regression line
plt.plot(prediction_space, y_pred, color='black', linewidth=3)
plt.show()
